# %% [markdown]
# ## Data Pizza

# %%
import re, random, time


class PizzaHouseRegistr:
    #Qeydiyyati olan userlar
    __users = [
        {
            "user_name": "Sebuhi",
            "user_password": "sebuhi123",
            "user_email": "sebuhi123@gmail.com",
            "user_mobile":"+994512002020",
        },
        {
            "user_name": "Nijat",
            "user_password": "Nijat123",
            "user_email": "Nijat123@gmail.com",
            "user_mobile":"+994512002021",
        },
        {
            "user_name": "Khadija",
            "user_password": "Khadija123",
            "user_email": "Khadija123@gmail.com",
            "user_mobile":"+994512002022",
        }        
    ]

    def program(
        self,
    ):
        choice = self.menu()
        if choice == "1":
            self.entry()
        if choice == "2":
            self.register()
        if choice == "3":
            self.exit()

    def menu(self):
        def control(choice):
            if re.search("[^1-3]", choice):
                raise Exception("Xaiş olunur 1 və 3 arasında keçərli rəqəm daxil edin.")
            elif len(choice) != 1:
                raise Exception("Xaiş olunur 1 və 3 arasında keçərli rəqəm daxil edin.")

        while True:
            try:
                choice = input(
                    "Xoş gəldiniz.\n\n[1]-Giriş\n[2]-Qeydiyyat\n[3]-Çıxış\n\n"
                )
                control(choice)
            except Exception as error:
                print(error)
                time.sleep(1.5)
            else:
                break
        return choice

    def entry(
        self,
    ):
        print("Giriş səhifəsinə yönləndirilirsiniz...")
        time.sleep(1.5)
        user_email = input("Emaili daxil edin...")
        user_password = input("Parolu daxil edin...")
        result = self.entry_control(user_email, user_password)
        if result == True:
            self.entry_successful()

        else:
            self.entry_unsuccessful()

    def entry_control(self, user_email, user_password):
        for user in self.__users:
            if (
                user["user_email"] == user_email
                and user["user_password"] == user_password 
            ):
                return True

        return False

    def entry_successful(
        self,
    ):
        print("Məlumatlar yoxlanılır...")
        time.sleep(1.5)
        print("Giriş uğurlu.\n\n")
        time.sleep(1.5)
        PizzaHouse1.pizza_program()

    def entry_unsuccessful(
        self,
    ):
        print("Məlumatlarınız yoxlanılır...")
        time.sleep(1.5)
        print("Email və ya parolda səhflik var.")
        time.sleep(1.5)

        def control_unsuccessful(choice_):
            if re.search("[^1-2]", choice_):
                raise Exception("Xaiş olunur 1 və 2 arasında keçərli rəqəm daxil edin.")
            elif len(choice_) != 1:
                raise Exception("Xaiş olunur 1 və 2 arasında keçərli rəqəm daxil edin.")

        while True:
            try:
                choice_ = input(
                    "Yenidən cəht etmək üçün 1-ə,Ana səhifəyə qayıtmaq üçün 2-yə basın"
                )
                control_unsuccessful(choice_)
            except Exception as error:
                print(error)
                time.sleep(1.5)
            else:
                break
        if choice_ == "1":
            self.entry()
        else:
            print("Ana səhifəyə yönləndirilirsiniz...")
            time.sleep(1.5)
            self.program()

    def register(
        self,
    ):
        print("Qeydiyyat səhifəsinə yönləndirilirsiniz...")
        time.sleep(1.5)

        def user_name_control(user_name_register):
            if not user_name_register.isalpha():
                raise Exception("İstifadəçi adınız ancaq hərflərdən ibarət olmalıdır.")
            return False

        while True:
            try:
                user_name_register = input("İstifadəçi adınızı daxil edin...")
                user_name_control(user_name_register)
            except Exception as error_name:
                print(error_name)
                time.sleep(1.5)
            else:
                break
        self.password_register = input("Şifrə daxil edin...")
        def user_mobile_control(user_mobile):
            if len(user_mobile)!=9:
                raise Exception("Daxil etdiyiniz nömrə düzgün qeyd edilməyib.Zəhmət olmazsa yenidən cəhd edin!")
            elif user_mobile.isalpha():
                raise Exception("Mobil nömrə rəqəmlərdən ibarət olmalıdır!")
            return False
      
        while True:
            try:
                user_mobile = input("Mobil nömrənizi daxil edin: +994 ")
                user_mobile_control(user_mobile)
            except Exception as error_mobile:
                print(error_mobile)
                time.sleep(1.5)
            else:
                break                 
            

        def email_control(email_register):
            if not bool(re.search("@" and ".com", email_register)):
                raise Exception("Uyğun email daxil edin...Misal: admin@gmail.com")
            return False

        while True:
            try:
                email_register = input("Emailinizi daxil edin...")
                email_control(email_register)
            except Exception as error_email:
                print(error_email)
                time.sleep(1.5)
            else:
                break
        if self.check_registration(user_name_register, email_register):
            print("Məlumatlarınız yoxlanılır...")
            time.sleep(1.5)
            print("Bu emailda sistemdə istifadəçi vardır.")
            time.sleep(1.5)
            print("Emalinizi dəyişdirib yenidən cəht edin...\n")
            time.sleep(1.5)
            self.register()
        else:
            print("Məlumatlarınız yoxlanılır...\n")
            time.sleep(2)
            print("Qeydiyyat uğurla başa çatdı.\n\n")
            time.sleep(1.5)
            self.__users.append(
                {
                    f"user_name": "{user_name_register}",
                    "user_password": "{password_register}",
                    "user_email": "{email_register}",
                    "user_mobile":"+994"+"{user_mobile}",
                }
            )
            PizzaHouse1.pizza_program()

    def check_registration(self, user_name_register, email_register):
        for user in self.__users:
            if (
                user["user_email"] == email_register
            ):
                return True
        return False

    def exit(
        self,
    ):
        print("Saytdan çıxılır...")
        time.sleep(1.5)
        self.period = False
        exit()


class PizzaHouse:
    total_catches_ = []
    __pizzalar = [
        {
            "pizza_id": 1,
            "pizza_name": "Amerikan Hot",
            "pizza_composition": "Pizza Sous, Mozzarella pendiri, Pepperoni və Halapenyo Bibəri",
            "pizza_price": 5.50,
        },
        {
            "pizza_id": 2,
            "pizza_name": "Qril Çiken Parmezan",
            "pizza_composition": "Sarımsaqlı Parmezan sousu, Qril Toyuğu, Vetçina, Pomidor, Mozzarella Pendiri, Halapeno Bibəri",
            "pizza_price": 5.50,
        },
        {
            "pizza_id": 3,
            "pizza_name": "Acılı Çiken Ranç",
            "pizza_composition": "Ranch Sousu, Toyuq Əti, Göbələklər,  Halapenyo Bibəri, Təzə Doğranmış Pomidorlar və Mozzarella Pendiri",
            "pizza_price": 6,
        },
        {
            "pizza_id": 4,
            "pizza_name": "Karnaval",
            "pizza_composition": "Pizza Sous, Göbələk, Qara Zeytun, Pepperoni, Mozzarella",
            "pizza_price": 5,
        },
        {
            "pizza_id": 5,
            "pizza_name": "Çiken Barbekyu",
            "pizza_composition": "Qril Toyuq, Göbələk, Barbekyu Sousu, Mozzarella Pendiri",
            "pizza_price": 5.70,
        },
        {
            "pizza_id": 6,
            "pizza_name": "Cheddar Çiken Club",
            "pizza_composition": "Qril toyuğu, Pomidor, Vetçina, Mozzarella, Cheddar, Ranç sousu",
            "pizza_price": 6.70,
        },
        {
            "pizza_id": 7,
            "pizza_name": "Aylend Spays",
            "pizza_composition": "Sarımsaq Sousu, Qril Toyuğu, Ananas, Pomidor, Mozzarella Pendiri, Halapeno bibəri, Çili Pul Bibəri",
            "pizza_price": 6.20,
        },
        {
            "pizza_id": 8,
            "pizza_name": "Çiken Parmezan",
            "pizza_composition": "Toyuq Poppersləri, Parmesan, Göbələk, İtalyan Ədviyyatları, Mozzarella Pendiri, Sarımsaq Sousu",
            "pizza_price": 5.20,
        },
        {
            "pizza_id": 9,
            "pizza_name": "Nyu Orleans",
            "pizza_composition": "Qarğıdalı, Qril Toyuq, Göbələk, Yaşıl Bibər, Sarımsaq Sousu, Mozzarella Pendiri",
            "pizza_price": 5.40,
        },
        {
            "pizza_id": 10,
            "pizza_name": "Marinera",
            "pizza_composition": "Ton Balığı, Yaşıl Bibər, Qara Zeytun, Mozzarella Pendiri",
            "pizza_price": 5.50,
        },
    ]
    __drinks = [
        {
            "drink_id": 1,
            "drink_name": "CocoCola",
            "drink_price": 2.50,
        },
        {
            "drink_id": 2,
            "drink_name": "Fanta",
            "drink_price": 2.30,
        },
        {
            "drink_id": 3,
            "drink_name": "Pepsi",
            "drink_price": 2.20,
        },
    ]
    __sauce = [
        {
            "sauce_id": 1,
            "sauce_name": "Ketchup",
            "sauce_price": 0.40,
        },
        {
            "sauce_id": 2,
            "sauce_name": "BBQ sauce",
            "sauce_price": 0.60,
        },
        {
            "sauce_id": 3,
            "sauce_name": "Cheese sauce",
            "sauce_price": 0.50,
        },
    ]
    __composition = [
        "Qril Toyuqu",
        "Cheddar",
        "Ananas",
        "Pomidor",
        "Sous",
        "Göbələk",
        "Zeytun",
        "Pepperoni",
        "Mozzarella",
        "Bibər",
        "Sarımsaq Sousu",
        "Yaşıl Bibər",
        "Acı Bibər",
        "Və siz nə istəsəniz..",
    ]

    def pizza_program(
        self,
    ):
        choice_product = self.product_menu()
        if choice_product == "1":
            self.pizza_choice()
        if choice_product == "2":
            self.drink_choice()
        if choice_product == "3":
            self.sauce_choice()
        if choice_product == "4":
            self.order_end()

    def product_menu(
        self,
    ):
        def product_control(choice_product):
            if re.search("[^1-4]", choice_product):
                raise Exception("Xaiş olunur 1 və 3 arasında keçərli rəqəm daxil edin.")
            elif len(choice_product) != 1:
                raise Exception("Xaiş olunur 1 və 3 arasında keçərli rəqəm daxil edin.")

        while True:
            try:
                choice_product = input(
                    "Ana menuya xoş gəldiniz.\n\n[1]-Pizzalar\n[2]-İçkilər\n[3]-Souslar\n[4]-Çıxış(Sifarişi bitir.)\n\n"
                )
                product_control(choice_product)
            except Exception as error:
                print(error)
                time.sleep(2)
            else:
                break
        return choice_product

    def pizza_choice(
        self,
    ):
        print("Pizzalar menusuna yönləndirilirsiniz...\n")
        time.sleep(2)
        print(
            "Pizza seçin: \n\n[1]-Amerikan Hot\n[2]-Qril Çiken Parmezan\n[3]-Acılı Çiken Ranç\n[4]-Karnaval\n[5]-Çiken Barbekyu\n[6]-Cheddar Çiken Club\n[7]-Aylend Spays\n[8]-Çiken Parmezan\n[9]-Nyu Orleans\n[10]-Marinera\n[11]-Öz pizzanı yarat"
        )
        def pizza_control(choice_product):
            if re.search("[^0-9]", choice_product):
                raise Exception("Xaiş olunur 0 və 11 arasında keçərli rəqəm daxil edin.")

        while True:
            try:
                pizza_ind = input()
                pizza_control(pizza_ind)
            except Exception as pizza_error:
                print(pizza_error)
                time.sleep(2)
            else:
                break
        pizza_ind=int(pizza_ind)
        
        if pizza_ind == 11:
            print("Öz pizzanı yarat menusu açılır...\n")
            time.sleep(1.5)
            self.create_pizza()
        else:
            for pizza in self.__pizzalar:
                if pizza["pizza_id"] == pizza_ind:
                    time.sleep(1)
                    yesno = input("Pizza tərkibini görmək isdəyirsinizmi? (y/n)\n")
                    if yesno.lower() == "y":
                        print(
                            "Pizza tərkibi: \n\n{}".format(
                                "\n".join(pizza["pizza_composition"].split(", "))
                            )
                        )
                    time.sleep(1.5)
                    yesno = input("\nPizzanı satın almaq isdəyirsinizmi? (y/n)\n")
                    time.sleep(1.5)
                    if yesno.lower() == "y":
                        self.pizza_buy(pizza)
                    else:
                        yesno = input(
                            "Pizza seçimlərinə dönmək üçün 1, Məhsul seçimlərinə dönmək üçün 2-yə basın."
                        )
                        if yesno == "1":
                            self.pizza_choice()
                        else:
                            self.product_menu()

    def create_pizza(
        self,
    ):
        print("Ingredients: \n\n{}\n".format("\n".join(self.__composition)))
        time.sleep(1.5)
        ingredients = input("İngredientləri vergüllə daxil edin: ").split(",")
        time.sleep(1.5)
        print("İstəyləriniz qeyd olundu...")
        pizza_price = len(ingredients) * 0.7
        time.sleep(1.5)
        edge_thickness = input("\n\nXəmir qalınlığı:\n\n[1]-Ənənəvi\n[2]-Nazik\n")
        time.sleep(1.5)
        size = input("\nÖlçü:\n\n[1]-Kiçik\n[2]-Orta\n[3]-Böyük\n")
        pizza_total_catches = 0
        if edge_thickness == "1":
            edge_pizza_catch = pizza_price * 1.2
            if size == 1:
                pizza_total_catches = pizza_total_catches + edge_pizza_catch * 1.2
            elif size == 2:
                pizza_total_catches = pizza_total_catches + edge_pizza_catch * 1.4
            else:
                pizza_total_catches = pizza_total_catches + edge_pizza_catch * 1.6
        elif edge_thickness == "2":
            edge_pizza_catch = pizza_price * 1.4
            if size == 1:
                pizza_total_catches = pizza_total_catches + edge_pizza_catch * 1.2
            elif size == 2:
                pizza_total_catches = pizza_total_catches + edge_pizza_catch * 1.4
            else:
                pizza_total_catches = pizza_total_catches + edge_pizza_catch * 1.6
        print("Pizzanızın qiyməti hesablanır...")
        time.sleep(1.5)
        print("Bir ədəd Öz pizzanızın qiyməti: %.2f" % pizza_total_catches)
        time.sleep(1.5)
        number = int(input("\nPizza sayını daxil edin: \n"))
        time.sleep(1.5)
        pizza_total_catches = pizza_total_catches * number
        print("Toplam Tutar : %.2f" % pizza_total_catches, end="\n\n")
        self.order(pizza_total_catches)

    def pizza_buy(self, pizza):
        pizza_total_catches = 0
        edge_thickness = input("\n\nXəmir qalınlığı\n\n[1]-Ənənəvi\n[2]-Nazik\n")
        time.sleep(1.5)
        size = input("\nÖlçü: \n\n[1]-Kiçik\n[2]-Orta\n[3]-Böyük\n")
        if edge_thickness == "1":
            edge_pizza_catch = pizza["pizza_price"] * 1.2
            if size == 1:
                pizza_total_catches = pizza_total_catches + edge_pizza_catch * 1.2
            elif size == 2:
                pizza_total_catches = pizza_total_catches + edge_pizza_catch * 1.4
            else:
                pizza_total_catches = pizza_total_catches + edge_pizza_catch * 1.6
        elif edge_thickness == "2":
            edge_pizza_catch = pizza["pizza_price"] * 1.4
            if size == 1:
                pizza_total_catches = pizza_total_catches + edge_pizza_catch * 1.2
            elif size == 2:
                pizza_total_catches = pizza_total_catches + edge_pizza_catch * 1.4
            else:
                pizza_total_catches = pizza_total_catches + edge_pizza_catch * 1.6
        print(
            "Bir ədəd {} qiyməti: %.2f ".format(pizza["pizza_name"])
            % pizza_total_catches
        )
        time.sleep(1.5)
        number = int(input("Pizza sayını daxil edin: \n"))
        pizza_total_catches = pizza_total_catches * number
        print("\nToplam Tutar : %.2f " % pizza_total_catches, end="\n\n")
        self.order(pizza_total_catches)

    def drink_choice(
        self,
    ):
        print("İçkilər menusuna yönləndirilirsiniz...\n")
        time.sleep(1.5)
        print("İçki seçin: \n\n[1]-CocoCola\n[2]-Fanta\n[3]-Pepsi\n")
        drink_id = int(input())
        for drink in self.__drinks:
            if drink["drink_id"] == drink_id:
                yesno = input(
                    "İçkinin qiyməti : %.2f İçkini satın almaq isdəyirsinizmi? (y/n)\n"
                    % drink["drink_price"]
                )
                if yesno.lower() == "y":
                    self.drink_buy(drink["drink_price"])
                else:
                    self.pizza_program()

    def drink_buy(self, drink):
        drink_total_catches = 0
        number = int(input("İçki sayını daxil edin: "))
        drink_total_catches = drink * number
        print("Toplam tutar %.2f " % drink_total_catches, end="\n\n")
        self.order(drink_total_catches)

    def sauce_choice(
        self,
    ):
        print("Souslar menusuna yönləndirilirsiniz...\n")
        time.sleep(1.5)
        print("Sous seçin: \n\n[1]-Ketchup\n[2]-BBQ sauce\n[3]-Cheese sauce\n")
        sauce_id = int(input())
        for sauce in self.__sauce:
            if sauce["sauce_id"] == sauce_id:
                yesno = input(
                    "Sous qiyməti : %.2f Sousu satın almaq isdəyirsinizmi? (y/n)\n"
                    % sauce["sauce_price"]
                )
                if yesno.lower() == "y":
                    self.sauce_buy(sauce["sauce_price"])
                else:
                    self.pizza_program()

    def sauce_buy(self, sauce):
        sauce_total_catches = 0
        number = int(input("Sous sayını daxil edin: "))
        sauce_total_catches = sauce * number
        print("Toplam tutar {} ".format(sauce_total_catches), end="\n\n")
        self.order(sauce_total_catches)

    def product_total_catches(self, total_catches):
        self.total_catches_.append(total_catches)

    def order(self, total_catches):
        time.sleep(1.5)
        result = input(
            "[1]-Səbətə əlavə et\n[2]-Sifarişi ləğv et\n[3]-Sifarişi bitir\n"
        )
        if result == "1":
            self.product_total_catches(total_catches)
            time.sleep(2)
            self.pizza_program()
        elif result == "2":
            time.sleep(2)
            self.pizza_program()
        elif result == "3":
            time.sleep(2)
            self.product_total_catches(total_catches)
            self.order_end()

    def order_end(
        self,
    ):
        if sum(self.total_catches_) == 0:
            exit()
        yesno = input(
            "Sifarişinizi bitirmək istəyirsinizmi? Ümumi tutar : %.2f (y/n)\n" % sum(self.total_catches_)
            
        )
        if yesno.lower() == "y":
            total_catches = sum(self.total_catches_)
            PizzaCashier1.pay_cassa(total_catches)


class PizzaCashier:
    def order_method(
        self,
    ):
        product = input("Sifariş üsulunu seçin: \n\n[1]-Çatdırılma\n[2]-Burada\n")
        time.sleep(1.5)
        if product == "1":

            def adress_control(adress):
                if re.split(r"\s", adress)[0] not in [
                    "Baku",
                    "baku",
                    "Baki",
                    "baki",
                    "Bakı",
                    "bakı",
                ]:
                    raise Exception(
                        "Xaiş olunur Bakı ərazisindən kənar şəhər və rayon daxil etməyin"
                    )
                return False

            while True:
                try:
                    adress = input(
                        "Zəhmət olmasa ünvanınızı daxil edin:\nNümunə: 'Şəhər' 'Küçə' 'Mənzil'\n"
                    )
                    time.sleep(2)
                    adress_control(adress)
                except Exception as adress_error:
                    print(adress_error)
                    time.sleep(3)
                else:
                    break
            print("\nMəlumatlarınız qeyd olundu...\n")
            time.sleep(1.5)
            return True
        else:
            return True

    def payment_method(self):
        result = input("Ödəniş üsulunu seçin :\n\n[1]-Card\n[2]-Cash\n")
        time.sleep(1.5)
        if result == "2":
            return True
        elif result == "1":
            return False

    def amount_funk(self, total_catches):
        def amount_control(amount):
            if amount < total_catches:
                raise Exception("Zehmet olmasa düzgün məbləği daxil edin.")

        while True:
            try:
                amount = float(
                    input(
                        "Zəhmət olmasa ödəniləcək məbləği daxil edin.\nTip vermək istəyirsinizsə ödəniləcək məbləğdən əlavə məbləğ daxil edin.\nÖdəniləcək məbləğ : {} \n".format(
                            total_catches
                        )
                    )
                )
                time.sleep(1.5)
                amount_control(amount)
            except Exception as amount_error:
                print(amount_error)
                time.sleep(1.5)
            else:
                break
        return amount

    def cash_balance(self, amount, total_catches):
        cash_balance_total = amount - total_catches
        return cash_balance_total

    def tip_funk(self, cash_balance):
        def amount_tip_control(amount_tip):
            if amount_tip > cash_balance:
                raise Exception("Zehmet olmasa pul üstünə uyğun tip verməyə çalışın.\n")

        while True:
            try:
                amount_tip = int(input("Tip verəcəyiniz məbləği daxil edin: \n"))
                amount_tip_control(amount_tip)
            except Exception as amount_error:
                print(amount_error)
                time.sleep(1.5)
            else:
                break
        print("Tip üçün Təşəkkür edirik.")
        cash_balance = cash_balance - amount_tip
        return cash_balance

    def order_time(self):
        time = random.randrange(27, 30)
        if time < 30:
            return True
        else:
            return False

    def pay_cassa(self, total_catches):
        print("Sifarişiniz hazırlanır...")
        time.sleep(3)
        if self.order_time():
            print("Sifarişiniz hazırdır...\n")
            time.sleep(1.5)
            if self.order_method():
                if self.payment_method():
                    amount = self.amount_funk(total_catches)
                    cash_balance_ = self.cash_balance(amount, total_catches)
                    if amount > total_catches:
                        tip_msg = input("Tip vermək istəyirsinizmi? (y/n)\n")
                        if tip_msg.lower() == "y":
                            cash_balance_ = self.tip_funk(cash_balance_)

                    print("Sizin pul qalığı : %.2f" % cash_balance_)
                    print("Nuş olsun.")

                else:

                    def card_number_control(card_number):
                        if not card_number.isnumeric():
                            raise Exception(
                                "Sizin daxil etdiyiniz kart nömrəsi standartlara uyğun deyil.\nXaiş olunur ancaq rəqəmlərdən ibarət kart nömrəsi daxil edin.\n"
                            )
                        elif len(card_number) != 16:
                            raise Exception(
                                "Sizin daxil etdiyiniz kart nömrəsi standartlara uyğun deyil.\nXaiş olunur 16 rəqəmli kart nömrəsi daxil edin.\n"
                            )
                        return True

                    while True:
                        try:
                            card_number = input("Kart nömrənizi daxil edin: \n")
                            print("Məlumatlar yoxlanılır...\n")
                            time.sleep(2)
                            card_number_control(card_number)
                        except Exception as card_number_error:
                            print(card_number_error)
                            time.sleep(2)
                        else:
                            break
                    print(
                        "Məbləğ {} kartdan çəkildi.Qəbzi götürməyi unutmayın.".format(
                            card_number
                        )
                    )
                    time.sleep(2)
                    print("\nNuş olsun.")
        else:
            print(
                "Müəyyən problemlər səbəbi ilə sizin sifarişiniz gecikdiyi üçün bu sifarişiniz biz tərəfindən qarşılanır.Nuş olsun."
            )
            print("Sifarişiniz tezliklə hazırlanacaq.")


PizzaHouseRegistr1 = PizzaHouseRegistr()
PizzaCashier1 = PizzaCashier()
PizzaHouse1 = PizzaHouse()
PizzaHouseRegistr1.program()
# Out:
# Giriş səhifəsinə yönləndirilirsiniz...
# Məlumatlarınız yoxlanılır...
# Email və ya parolda səhflik var.
# Ana səhifəyə yönləndirilirsiniz...
# Saytdan çıxılır...
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
